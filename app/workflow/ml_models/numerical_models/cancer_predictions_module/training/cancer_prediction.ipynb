# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}\n")
# Out:
# Using device: cuda

# %%
# Load your cancer prediction dataset
import pandas as pd

# Replace with your actual data file path
df = pd.read_csv('cancer_predictions.csv')

# Or if you're loading it differently, show me how you loaded it in your original notebook

# %%
# %pip install optuna
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ...
# CANCER PREDICTION - TRAINING PIPELINE
# ...
# Dataset shape: (1500, 8)
# Number of features: 8
# Class distribution: [943 557]
#
# Train set: 1200 samples
# Test set: 300 samples
#
# Using device: cuda
# Positive class weight: 1.69
#
# ...
# TRAINING
# ...
# Epoch [10/100] - Train Loss: 0.4648, Val Loss: 0.3908, Val Acc: 0.8767
# Epoch [20/100] - Train Loss: 0.4414, Val Loss: 0.3681, Val Acc: 0.8800
# Epoch [30/100] - Train Loss: 0.4178, Val Loss: 0.3709, Val Acc: 0.8833
# Epoch [40/100] - Train Loss: 0.4127, Val Loss: 0.3677, Val Acc: 0.9000
# Epoch [50/100] - Train Loss: 0.3950, Val Loss: 0.3616, Val Acc: 0.8833
# Epoch [60/100] - Train Loss: 0.4047, Val Loss: 0.3600, Val Acc: 0.8867
# Epoch [70/100] - Train Loss: 0.4191, Val Loss: 0.3647, Val Acc: 0.8833
# Epoch [80/100] - Train Loss: 0.3910, Val Loss: 0.3579, Val Acc: 0.9033
# Epoch [90/100] - Train Loss: 0.3853, Val Loss: 0.3560, Val Acc: 0.8867
# Epoch [100/100] - Train Loss: 0.3554, Val Loss: 0.3494, Val Acc: 0.8867
#
# ...
# FINAL EVALUATION
# ...

# %%
import sys
sys.path.append("/home/mamou/Aws Hanaqtah/Health-Navigator")

from app.workflow.ml_models.numerical_models.cancer_predictions_module.Cancer_prediction import predict_cancer

data = {
    "Age": 58,
    "Gender": 1,
    "BMI": 16.085313321370478,
    "Smoking": 0,
    "GeneticRisk": 1,
    "PhysicalActivity": 8.146250560259173,
    "AlcoholIntake": 4.148219026764642,
    "CancerHistory": 1,
    "Diagnosis": 1
}

print(predict_cancer(data))
# Out:
# ✓ Cancer PyTorch model loaded safely
#
# {'prediction': 1, 'probability': 0.9884}
